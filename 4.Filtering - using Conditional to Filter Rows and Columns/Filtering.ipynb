# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)
filt = (df['last'] == 'Doe') & (df['first'] == 'Jane')
df[filt]
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[filt,'email']
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
filt = (schema_df['QuestionText'] == 'Do you code as a hobby?' )

# %%
schema_df[filt]
# Out:
#                      QuestionText
# Column
# Hobbyist  Do you code as a hobby?

# %%
df.loc[ :4 , 'MainBranch'  : 'Student' ]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
# 4                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
#
# ...

# %%
# Out:
# 'Less than once per year'

# %%
# Out:
# 'The quality of OSS and closed source software is about the same'

# %%
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
highsalary = (df['ConvertedComp'] > 70000)
df.loc[highsalary , ['MainBranch' , 'ConvertedComp' , 'Country'  ]]
# Out:
#                                                    MainBranch  ConvertedComp  \
# Respondent
# 6           I am not primarily a developer, but I write co...       366420.0
# 9                              I am a developer by profession        95179.0
# 13                             I am a developer by profession        90000.0
# 16                             I am a developer by profession       455352.0
# 22                             I am a developer by profession       103000.0
# ...                                                       ...            ...
# 88876                          I am a developer by profession       180000.0
# 88877                          I am a developer by profession      2000000.0
# 88878                          I am a developer by profession       130000.0
# 88879                          I am a developer by profession        82488.0
# 88882                          I am a developer by profession       588012.0
#
#                    Country
# ...

# %%
countries = ['Canada','India','United Kingdom']


filt = df['Country'].isin(countries)


df.loc[filt , 'Country']
# Out:
# Respondent
# 1        United Kingdom
# 6                Canada
# 8                 India
# 10                India
# 12               Canada
#               ...
# 84539    United Kingdom
# 85182            Canada
# 85961    United Kingdom
# 86012             India
# 88377            Canada
# Name: Country, Length: 18193, dtype: object

# %%
df.loc[filt , 'Country' ]
# Out:
# Respondent
# 1        United Kingdom
# 16       United Kingdom
# 76       United Kingdom
# 80       United Kingdom
# 82       United Kingdom
#               ...
# 79798    United Kingdom
# 80116    United Kingdom
# 82789    United Kingdom
# 84539    United Kingdom
# 85961    United Kingdom
# Name: Country, Length: 5737, dtype: object
